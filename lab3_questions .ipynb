# %% [markdown]
# ## Lab 3: pandas
#
# #### Introduction
#
# We will examine a dataset containing characteristics of lego sets manufactured between 1961 and 2019 from the BRICKSET website. Variables in the dataset are described below.
#
# | VARIABLE             |      DESCRIPTION             |
# |:----------|:-------------|
# | ID |  set id |
# | Name |    name of set   |
# | Themegroup | themegroup of set |
# | Theme |  theme of set |
# | Subtheme |    subtheme of set   |
# | Year | year released |
# | Pieces |  number of pieces |
# | Minifig |    number of minifigs   |
# | Package | type of packaging |
# | Retail_Price |  recommended retail pri
#
#
#
# Load pandas to read in the data and save it as dataframe named lego.

# %%
import pandas as pd

lego = pd.read_csv('lego.csv')

lego.sample(15)
# Out:
#             id                                             name  \
# 9733    1624-1                                    King's Archer
# 539    41620-1                                     Stormtrooper
# 10769   1965-1                   Building Set, Trial Size Offer
# 304    10757-1                              Raptor Rescue Truck
# 8626    6434-1                                  Roadside Repair
# 4594    3860-1                                   Castle Fortaan
# 742    71021-6                              Birthday Party Girl
# 6327    7706-1                              Mobile Defense Tank
# 8716    2279-1                                   Tubular Motion
# 7789   10017-1                                     Hopper Wagon
# 9605    1712-1                                    Crossbow Cart
# 14     10895-1  Emmet and Lucy's Visitors from the DUPLO Planet
# 1703   41113-1                                  Party Gift Shop
# 10358   6349-1                                    Holiday Villa
# 5371    5638-1                                          Postman
#
#              themegroup                    theme  \
# 9733         Historical                   Castle
# 539            Licensed               BrickHeadz
# 10769             Basic                    Basic
# 304              Junior                  Juniors
# 8626         Modern day                     Town
# 4594      Miscellaneous                    Games
# 742       Miscellaneous  Collectable Minifigures
# 6327   Action/Adventure                Exo-Force
# 8716         Pre-school                    Duplo
# 7789         Modern day                   Trains
# 9605         Historical                   Castle
# 14           Pre-school                    Duplo
# 1703              Girls                  Friends
# 10358        Modern day                     Town
# 5371         Pre-school                    Duplo
#
#                              subtheme    year  pieces  minifigs    package  \
# 9733                    Black Knights  1993.0    22.0         1        Box
# 539                         Star Wars  2018.0   124.0         0        Box
# 10769                             NaN  1985.0    32.0         1        NaN
# 304    Jurassic World: Fallen Kingdom  2018.0    85.0         2        Box
# 8626                             City  1999.0   210.0         5        Box
# 4594                          Heroica  2011.0   304.0        15        Box
# 742                         Series 18  2018.0     9.0         1  Foil pack
# 6327                         Original  2006.0   365.0         2        Box
# 8716                        Basic Set  1998.0    73.0         2     Bucket
# 7789                              9 V  2001.0   228.0         0        Box
# 9605                   Dragon Knights  1994.0    23.0         1    Polybag
# 14                                NaN  2019.0    53.0         2        Box
# 1703                            Party  2016.0    52.0         0        Box
# 10358                         Leisure  1988.0   205.0         2        Box
# 5371                       LEGO Ville  2009.0     9.0         1        NaN
#
#        retail_price
# 9733            NaN
# 539            9.99
# 10769          1.50
# 304           24.99
# 8626          50.00
# 4594          29.99
# 742            3.99
# 6327          30.00
# 8716            NaN
# 7789          20.00
# 9605           2.00
# 14            29.99
# 1703           4.99
# 10358           NaN
# 5371           9.99

# %% [markdown]
# #### Question 1:
# Some sets have missing information for retail_price or pieces or both. This could be because the sets are free (giveaways), they aren’t traditional lego sets (comic books, etc) or just because the information is missing. Filter the lego dataset based on the specifications below and save the result as lego. Hence, you will overwrite the original lego object. In addition, describe the implications of removing these sets.
#
# Your new lego (data frame) should have:
#
# • no missing pieces
#
# • only contain sets with a nonzero number of pieces
#
# • no missing retail_price
#
# • only contain sets with a nonzero retail_price
#
# • no missing year
#
# - Print out the shape of the dataframe after cleaning the dataset.
# -

# %%
# Write your answer here

#lego.shape

#lego.describe()

#lego.theme.unique()

#lego2 = lego2.loc[lego2.pieces == 0, :]
#print(lego2.shape)

#lego2 = lego2.loc[lego2.retail_price > 0, :]
#print(lego2.shape)

#print(lego.shape)
#lego2 = lego.dropna()
#print(lego2.shape)


lego2 = lego2.loc[lego2['pieces'].notna() & (lego2['pieces'] > 0), :]
print(f"After filtering pieces, the shape is: {lego2.shape}")

lego2 = lego2.loc[lego2['retail_price'].notna() & (lego2['retail_price'] > 0), :]
print(f"After filtering retail_price, the shape is: {lego2.shape}")

lego2 = lego2.loc[lego2['year'].notna(), :]
print(f"After filtering missing year values, the shape is: {lego2.shape}")

lego2 = lego2.dropna()
print(f"After removing any remaining missing data, the final shape is: {lego2.shape}")
# Out:
# After filtering pieces, the shape is: (4360, 10)
# After filtering retail_price, the shape is: (4277, 10)
# After filtering missing year values, the shape is: (4277, 10)
# After removing any remaining missing data, the final shape is: (4277, 10)

# %% [markdown]
# #### Question 2:
# Arrange the dataset in descending order of retail_price and print the first three rows. Report in words the names of the three most expensive lego sets, their prices, and how many pieces each has.

# %%
# Write your answer here

lego2.sort_values(by = 'retail_price', ascending = False).head(3)
# Out:
#            id                                    name themegroup      theme  \
# 1434  75192-1                       Millennium Falcon   Licensed  Star Wars
# 2065  75159-1                              Death Star   Licensed  Star Wars
# 5944  10179-1  Ultimate Collector's Millennium Falcon   Licensed  Star Wars
#
#                        subtheme    year  pieces  minifigs package  \
# 1434  Ultimate Collector Series  2017.0  7541.0         8     Box
# 2065  Ultimate Collector Series  2016.0  4016.0        27     Box
# 5944  Ultimate Collector Series  2007.0  5197.0         5     Box
#
#       retail_price
# 1434        799.99
# 2065        499.99
# 5944        499.99

# %% [markdown]
# #### Question 3:
#
# It appears that the most expensive sets generally have more pieces. Create a new variable (column) price_per_piece, representing the price in dollars per piece for each of the sets. Save the result as lego2. Hence, you will overwrite the current lego object.

# %%
# Write your answer here

lego2['price_per_piece'] = lego2.retail_price / lego2.pieces
lego2.sort_values(by = 'price_per_piece', ascending = False).head(5)
# Out:
#                id                                   name themegroup  \
# 5551       8878-1               Rechargeable Battery Box  Technical
# 5553       8887-1                     Transformer 10V DC  Technical
# 5616  COMCON005-1              Collectable Display Set 2   Licensed
# 8694       9755-1                     Temperature Sensor  Technical
# 7540       3805-1  Robotics Invention System Upgrade Kit  Technical
#
#                 theme       subtheme    year  pieces  minifigs      package  \
# 5551  Power Functions    Accessories  2009.0     1.0         0      Polybag
# 5553  Power Functions    Accessories  2009.0     1.0         0      Polybag
# 5616        Star Wars  Miscellaneous  2009.0     2.0         3  Plastic box
# 8694       Mindstorms            1.0  1999.0     1.0         0      Polybag
# 7540       Mindstorms            1.5  2001.0     1.0         0        Other
#
#       retail_price  price_per_piece
# 5551         49.99           49.990
# 5553         29.99           29.990
# 5616         49.99           24.995
# 8694         24.00           24.000
# 7540         20.00           20.000

# %% [markdown]
# #### Question 4:
#
# Arrange the lego2 dataset in descending order of price_per_piece and return only the columns: name, themegroup, theme, pieces, price_per_piece, and the first five rows. What do you notice about these sets?

# %%
# Write your answer here

lego2.sort_values(by = 'price_per_piece', ascending = False).loc[ : , ['name', 'themegroup', 'theme', 'pieces', 'price_per_piece']].head(5)
# Out:
#                                        name themegroup            theme  \
# 5551               Rechargeable Battery Box  Technical  Power Functions
# 5553                     Transformer 10V DC  Technical  Power Functions
# 5616              Collectable Display Set 2   Licensed        Star Wars
# 8694                     Temperature Sensor  Technical       Mindstorms
# 7540  Robotics Invention System Upgrade Kit  Technical       Mindstorms
#
#       pieces  price_per_piece
# 5551     1.0           49.990
# 5553     1.0           29.990
# 5616     2.0           24.995
# 8694     1.0           24.000
# 7540     1.0           20.000

# %% [markdown]
# #### Question 5:
#
# What is the mean price_per_piece for the top 40 'Toy Story' sets in terms of price_per_piece?

# %%
# Write your answer here

lego3 = lego2.sort_values(by = 'price_per_piece' , ascending = False )
lego3.loc[lego3.theme == 'Toy Story' , :].head(40).price_per_piece.mean()
# Out:
# 0.16089862892544177

# %% [markdown]
# #### Question 6:
#
# What are the unique themes in the lego dataset?

# %%
# Write your answer here

lego2.theme.value_counts()
# Out:
# theme
# Star Wars                            498
# Collectable Minifigures              431
# City                                 390
# Town                                 310
# Racers                               183
#                                     ...
# The Lego Movie 2: The Second Part      2
# Explore                                1
# Bricks and More                        1
# Books                                  1
# LEGOLAND                               1
# Name: count, Length: 73, dtype: int64
